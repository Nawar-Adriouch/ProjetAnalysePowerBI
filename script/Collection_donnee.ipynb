# %%
from bs4 import BeautifulSoup
import requests
import re
url="""https://www.mubawab.ma/fr/cd/casablanca/ain-chock/immobilier-a-vendre-all:sc:apartment-sale,commercial-sale,farm-sale,house-sale,land-sale,office-sale,other-sale,riad-sale,villa-sale?indexedSearchId=&type=ad&transactionId=sale&adTypeIds=%5B%22house-sale%22%2C%22villa-sale%22%2C%22riad-sale%22%2C%22commercial-sale%22%2C%22office-sale%22%2C%22land-sale%22%2C%22other-sale%22%2C%22farm-sale%22%5D&cityIds=%5B%5D&townIds=%5B2024%5D&pushWebHash=&sh=&filterCitySearchBox%3AfilterCitySearchBoxHidden=&minPrice%3AminPriceHidden=&maxPrice%3AmaxPriceHidden=&minSurface%3AminSurfaceHidden=&maxSurface%3AmaxSurfaceHidden=&minRooms=&transaction%3AtransactionHidden=sale&promotion=false&secondHand=false&elevator=false&storageRoom=false&heating=false&airConditioning=false&fullKitchen=false&doubleGlazing=false&garage=false&garden=false&pool=false&reinforcedDoor=false&security=false&terrace=false&_csrf=eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJjc3JmVG9rZW4iLCJleHAiOjE3NjgwODMwOTR9.UZEm2hZ3l_gfzgBG9sQ0tMJ56S5YXu02oMIVAkM52rQQLOCiqxR_Sm3XNZiXi5YJBAZrdTMApq76EAN5E8V-_A"""
output=requests.get(url)
content_html=output.text
soup=BeautifulSoup(content_html,'html.parser')
data = []
ZONE_FIXE = "Aïn Chock"

for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)

    for p in paragraphs:
        texte = p.text.lower()

        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_FIXE,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })
print(data)
print(len(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8 data = []
#       9 ZONE_FIXE = "Aïn Chock"
# ---> 11 for info in informations:
#      12     prix_tag = info.find("span", class_=lambda x: x and "price" in x)
#      13     prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None
#
# NameError: name 'informations' is not defined

# %%
from bs4 import BeautifulSoup
import requests
url=""" https://www.mubawab.ma/fr/sd/casablanca/a%C3%AFn-seba%C3%A2/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")

ZOne = "Aïn Sbaa"

for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZOne,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/anfa/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")

zone_fixe="Anfa"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": zone_fixe,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/hay-hassani/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
Zone="Hay Hassani"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": Zone,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       8 soup=BeautifulSoup(html_content,"html.parser")
#       9 Zone="Hay Hassani"
# ---> 10 for info in informations:
#      11     prix_tag = info.find("span", class_=lambda x: x and "price" in x)
#      12     prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None
#
# NameError: name 'informations' is not defined

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/bernoussi/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE="Sidi Bernoussi"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/ma%C3%A2rif/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_="Maarif"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sc/villas-et-maisons-de-luxe-a-vendre:tw:2187,2188"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_1="Oasis"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_1,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sc/villas-et-maisons-de-luxe-a-vendre:tw:2197,2198"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_2="Oasis"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_2,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""http://mubawab.ma/fr/sd/casablanca/palmier/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_3="Palmier"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_3,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/ain-diab-extension/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_4="Ain Diab"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_4,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sc/villas-et-maisons-de-luxe-a-vendre:tw:2025,2026"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_4="Ain Diab"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_4,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/el-manar---el-hank/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_5="Al Manar"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_5,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/sd/casablanca/sidi-moumen/villas-et-maisons-de-luxe-a-vendre"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_6="Sidi moumen"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_6,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/cd/casablanca/centre-ville/immobilier-a-vendre-all:sc:apartment-sale,villa-sale"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_7="Centre Ville"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_7,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/cd/casablanca/mers-sultan/immobilier-a-vendre-all:sc:apartment-sale,villa-sale"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_8="Mers Saltan"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_8,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import string
url="""https://www.mubawab.ma/fr/cd/casablanca/sidi-belyout/immobilier-a-vendre-all:sc:apartment-sale,villa-sale"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_9="Sidi Belyot"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_9,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
# Out:
# [{'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '1230000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 57, 'Prix_Total': '620000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '17000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': None, 'Prix_Total': '5200000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 650, 'Prix_Total': '12000000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': None, 'Prix_Total': '740000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 641, 'Prix_Total': '5769000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 296, 'Prix_Total': 'À partir de 1332000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Appartement', 'Surface_m2': 114, 'Prix_Total': '1300000 DH'}, {'Zone': 'Aïn Chock', 'Type_Bien': 'Villa', 'Surface_m2': 323, 'Prix_Total': '8000000 DH'}, {'Zone': 'Aïn Chock', 'Type_B
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re 
import pandas as pd
import string
url="""https://www.mubawab.ma/fr/cd/casablanca/ain-borja/immobilier-a-vendre-all:sc:apartment-sale,villa-sale"""
output=requests.get(url)
html_content=output.text
soup=BeautifulSoup(html_content,"html.parser")
ZONE_0="Ain borja"
for info in informations:
    prix_tag = info.find("span", class_=lambda x: x and "price" in x)
    prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None

    surface = None
    type_bien = "Inconnu"

    paragraphs = info.find_all("p", class_=lambda x: x and "listingP" in x)
    for p in paragraphs:
        texte = p.text.lower()
        match = re.search(r'(\d+)\s*m²', texte)
        if match:
            surface = int(match.group(1))

        if "villa" in texte:
            type_bien = "Villa"
        elif "appartement" in texte:
            type_bien = "Appartement"
        elif "maison" in texte:
            type_bien = "Maison"

    if type_bien == "Inconnu":
        type_bien = "Appartement" 

    data.append({
        "Zone": ZONE_0,
        "Type_Bien": type_bien,
        "Surface_m2": surface,
        "Prix_Total": prix
    })

print(data)
print(len(data))
df = pd.DataFrame(data)
df.to_excel("dataFonciers.xlsx", index=False)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       9 soup=BeautifulSoup(html_content,"html.parser")
#      10 ZONE_0="Ain borja"
# ---> 11 for info in informations:
#      12     prix_tag = info.find("span", class_=lambda x: x and "price" in x)
#      13     prix = prix_tag.text.strip().replace("\xa0","") if prix_tag else None
#
# NameError: name 'informations' is not defined

# %%
import pandas as ps
df = ps.DataFrame(data)
df.to_excel("dataFonciers.xlsx", index=False)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
